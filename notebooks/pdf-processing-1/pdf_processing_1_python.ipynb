# %% [markdown]
# <a href="https://colab.research.google.com/github/j-sathurjan/data-prep-kit-examples/blob/main/notebooks/pdf-processing-1/pdf_processing_1_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Processing PDFs using Data Prep Kit
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/IBM/data-prep-kit/blob/dev/examples/notebooks/pdf-processing-1/pdf_processing_1_python.ipynb)
#
# This notebook will introduce DPK and showcase some of it's capabilities.
#
# Here is the workflow:
#
# - pdf2parquet: Extract text from PDF documents
# - docid: compute hashes
# - exact dedupe : filter out identical documents
# - fuzzy dedupe : filter out 'near duplicates'
# - document quality: scoring documents for quality
#
# ![](https://raw.githubusercontent.com/IBM/data-prep-kit/dev/examples/notebooks/pdf-processing-1/images/data-prep-kit-3-workflow.png)

# %% [markdown]
# ## How to run this notebook
#
# Two options:
#
# - **Option 1 - Google Colab:** easiest option.  no setup required.  Click this link to open this on google colab.  [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/IBM/data-prep-kit/blob/dev/examples/notebooks/pdf-processing-1/pdf_processing_1_python.ipynb)
# - **Option 2 - Local python dev environment:**  Setup using this [guide](../../../README.md#-getting-started)
#
# The notebook will work as in both environments

# %% [markdown]
# ## Step-1: Figure out Runtime Environment
#
# ### 1.1 - Determine runtime
#
# Determine if we are running on Google colab or local python environment

# %%
import os

if os.getenv("COLAB_RELEASE_TAG"):
   print("Running in Colab")
   RUNNING_IN_COLAB = True
else:
   print("NOT in Colab")
   RUNNING_IN_COLAB = False
# Out:
# Running in Colab

# %% [markdown]
# ### 1.2 - Install dependencies if running on Google Colab

# %%
# %%capture

if RUNNING_IN_COLAB:
    ! pip install  --default-timeout=100  \
        data-prep-toolkit-transforms[all]==1.0.0 \
        humanfriendly

# %% [markdown]
# ### 1.3 - Restart Runtime
#
# After installing dependencies, be sure <font color="red">restart runtime</font>, so libraries will be loaded
#
# You do this by going to **`Runtime --> Restart Session`**
#
# Then you can continue to the next step (no need to re-run the notebook)

# %% [markdown]
# ## Step-2: Configuration  & Utils

# %% [markdown]
# ### 2.1 - Basic Config

# %%
import os

if os.getenv("COLAB_RELEASE_TAG"):
   print("Running in Colab")
   RUNNING_IN_COLAB = True
else:
   print("NOT in Colab")
   RUNNING_IN_COLAB = False
# Out:
# Running in Colab

# %% [markdown]
# ### 2.2 - Setup input/outpur directories

# %%
import os, sys
import shutil

if RUNNING_IN_COLAB:
    input_dir = "input"
    shutil.os.makedirs(input_dir, exist_ok=True)
else:
    input_dir = "../../data-files/pdf-processing-1/"

output_dir = "output"

output_pdf2pq_dir = os.path.join (output_dir, '01_pdf2pq_out')
output_docid_dir = os.path.join (output_dir, '02_docid_out')
output_exact_dedupe_dir = os.path.join (output_dir, '03_exact_dedupe_out')
output_fuzzy_dedupe_dir = os.path.join (output_dir, '04_fuzzy_dedupe_out')
output_doc_quality_dir = os.path.join (output_dir, '05_doc_quality_out')
output_final_dir = os.path.join (output_dir, 'output_final')

## clear output folder
shutil.rmtree(output_dir, ignore_errors=True)
shutil.os.makedirs(output_dir, exist_ok=True)
print ("✅ Cleared output directory")
# Out:
# ✅ Cleared output directory

# %% [markdown]
# ### 2.3 - Handy Utils

# %%
import os
import requests
from humanfriendly import format_size
import pandas as pd
import glob

## Reads parquet files in a folder into a pandas dataframe
def read_parquet_files_as_df (parquet_dir):
    parquet_files = glob.glob(f'{parquet_dir}/*.parquet')
    # read each parquet file into a DataFrame and store in a list
    dfs = [pd.read_parquet (f) for f in parquet_files]
    dfs = [df for df in dfs if not df.empty]  # filter out empty dataframes
    # Concatenate all DataFrames into a single DataFrame
    if len(dfs) > 0:
        data_df = pd.concat(dfs, ignore_index=True)
        return data_df
    else:
        return pd.DataFrame() # return empty df
# ------------


def download_file(url, local_file, chunk_size=1024*1024):
    """
    Downloads a remote URL to a local file.

    Args:
        url (str): The remote URL.
        local_filename (str): The name of the local file to save the downloaded content.
        chunk_size (int): The size in bytes of each chunk. Defaults to 1024.

    Returns:
        None

    Example usage:
        download_file('http://example.com/file.txt', 'file.txt', chunk_size=1024*1024)  # Download in chunks of 1MB
    """
    # Check if the local file already exists
    if os.path.exists(local_file):
        file_size = format_size(os.path.getsize(local_file))
        print(f"Local file '{local_file}' ({file_size}) already exists. Skipping download.")
        return

    # Create the directory if it doesn't exist
    os.makedirs(os.path.dirname(local_file), exist_ok=True)

    # Stream the file download
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(local_file, 'wb') as f:
            for chunk in r.iter_content(chunk_size=chunk_size):
                if chunk: # filter out keep-alive new chunks
                    f.write(chunk)
        print()
        file_size = format_size(os.path.getsize(local_file))
        print(f"{local_file} ({file_size}) downloaded successfully.")
## --- end: download_file ------

# %% [markdown]
# ## Step-3: Inspect the Data
#
# We will use simple PDFs.  The files are [here](https://github.com/IBM/data-prep-kit/tree/dev/examples/data-files/pdf-processing-1/)
#
# - [earth.pdf](https://raw.githubusercontent.com/IBM/data-prep-kit/dev/examples/data-files/pdf-processing-1/earth.pdf) and exact duplicate [earth-copy.pdf](https://raw.githubusercontent.com/IBM/data-prep-kit/dev/examples/data-files/pdf-processing-1/earth-copy.pdf)
# - [earth2.pdf](https://raw.githubusercontent.com/IBM/data-prep-kit/dev/examples/data-files/pdf-processing-1/earth2.pdf) almost similar to earth.pdf (ONE word difference!)
# - [mars.pdf](https://raw.githubusercontent.com/IBM/data-prep-kit/dev/examples/data-files/pdf-processing-1/mars.pdf)
# - [spam.pdf](https://raw.githubusercontent.com/IBM/data-prep-kit/dev/examples/data-files/pdf-processing-1/spam.pdf) - contains spammy contents
# - [lorem-ipsum.pdf](https://raw.githubusercontent.com/IBM/data-prep-kit/dev/examples/data-files/pdf-processing-1/lorem-ipsum.pdf) - contains 'lorem ipsum' placeholder

# %% [markdown]
# ### 3.1 -Download Data

# %%
if RUNNING_IN_COLAB:

    download_file ('https://raw.githubusercontent.com/IBM/data-prep-kit/dev/examples/data-files/pdf-processing-1/earth.pdf', os.path.join(input_dir, 'earth.pdf'))

    download_file ('https://raw.githubusercontent.com/IBM/data-prep-kit/dev/examples/data-files/pdf-processing-1/earth-copy.pdf', os.path.join(input_dir, 'earth-copy.pdf'))

    download_file ('https://raw.githubusercontent.com/IBM/data-prep-kit/dev/examples/data-files/pdf-processing-1/earth2.pdf', os.path.join(input_dir, 'earth2.pdf'))

    download_file ('https://raw.githubusercontent.com/IBM/data-prep-kit/dev/examples/data-files/pdf-processing-1/mars.pdf', os.path.join(input_dir, 'mars.pdf'))

    download_file ('https://raw.githubusercontent.com/IBM/data-prep-kit/dev/examples/data-files/pdf-processing-1/spam.pdf', os.path.join(input_dir, 'spam.pdf'))

    download_file ('https://raw.githubusercontent.com/IBM/data-prep-kit/dev/examples/data-files/pdf-processing-1/lorem-ipsum.pdf', os.path.join(input_dir, 'lorem-ipsum.pdf'))
else:
    print ('Using input files from : ', input_dir)
# Out:
# input/earth.pdf (58.53 KB) downloaded successfully.
#
# input/earth-copy.pdf (58.53 KB) downloaded successfully.
#
# input/earth2.pdf (58.53 KB) downloaded successfully.
#
# input/mars.pdf (57.87 KB) downloaded successfully.
#
# input/spam.pdf (24.87 KB) downloaded successfully.
#
# input/lorem-ipsum.pdf (25.72 KB) downloaded successfully.

# %% [markdown]
# ## Step-4: Extract Data from PDF (pdf2parquet)
#
# This step we will read PDF files and extract the text data.
#
# [Pdf2Parquet documentation](https://github.com/IBM/data-prep-kit/blob/dev/transforms/language/pdf2parquet/README.md)
#
# We use the [Docling package](https://github.com/DS4SD/docling).

# %% [markdown]
# ### 4.1 - Execute

# %%
# %%time

from dpk_pdf2parquet.transform_python import Pdf2Parquet
from dpk_pdf2parquet.transform import pdf2parquet_contents_types

STAGE = 1
print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_dir}' --> output='{output_pdf2pq_dir}'\n", flush=True)

result = Pdf2Parquet(input_folder= input_dir,
                    output_folder= output_pdf2pq_dir,
                    data_files_to_use=['.pdf'],
                    pdf2parquet_contents_type=pdf2parquet_contents_types.MARKDOWN,   # markdown
                    ).transform()

if result == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception (f"❌ Stage:{STAGE}  failed")
# Out:
# 🏃🏼 STAGE-1: Processing input='input' --> output='output/01_pdf2pq_out'
# 10:45:04 INFO - pdf2parquet parameters are : {'batch_size': -1, 'artifacts_path': None, 'contents_type': <pdf2parquet_contents_types.MARKDOWN: 'text/markdown'>, 'do_table_structure': True, 'do_ocr': True, 'ocr_engine': <pdf2parquet_ocr_engine.EASYOCR: 'easyocr'>, 'bitmap_area_threshold': 0.05, 'pdf_backend': <pdf2parquet_pdf_backend.DLPARSE_V2: 'dlparse_v2'>, 'double_precision': 8}
# INFO:dpk_pdf2parquet.transform:pdf2parquet parameters are : {'batch_size': -1, 'artifacts_path': None, 'contents_type': <pdf2parquet_contents_types.MARKDOWN: 'text/markdown'>, 'do_table_structure': True, 'do_ocr': True, 'ocr_engine': <pdf2parquet_ocr_engine.EASYOCR: 'easyocr'>, 'bitmap_area_threshold': 0.05, 'pdf_backend': <pdf2parquet_pdf_backend.DLPARSE_V2: 'dlparse_v2'>, 'double_precision': 8}
# 10:45:04 INFO - pipeline id pipeline_id
# INFO:data_processing.runtime.execution_configuration:pipeline id pipeline_id
# 10:45:04 INFO - code location None
# INFO:data_processing.runtime.execution_configuration:code location None
# 10:45:04 INFO - data factory data_ is using local data access: input_folder - input output_folder - output/01_pdf2pq_out
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ is using local data access: input_folder - input output_folder - output/01_pdf2pq_out
# 10:45:04 INFO - data factory data_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ max_files -1, n_sample -1
# 10:45:04 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.pdf'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.pdf'], files to checkpoint ['.parquet']
# 10:45:04 INFO - orchestrator pdf2parquet started at 2025-02-19 10:45:04
# INFO:data_processing.runtime.pure_python.transform_orchestrator:orchestrator pdf2parquet started at 2025-02-19 10:45:04
# 10:45:04 INFO - Number of files is 6, source profile {'max_file_size': 0.055823326110839844, 'min_file_size': 0.023715972900390625, 'total_file_size': 0.2709054946899414}
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Number of files is 6, source profile {'max_file_size': 0.055823326110839844, 'min_file_size': 0.023715972900390625, 'total_file_size': 0.2709054946899414}
# 10:45:04 INFO - Initializing models
# INFO:dpk_pdf2parquet.transform:Initializing models
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# README.md:   0%|          | 0.00/3.49k [00:00<?, ?B/s]
# model.pt:   0%|          | 0.00/202M [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.71k [00:00<?, ?B/s]
# (…)cts%2Ftableformer%2Ffat%2Ftm_config.json:   0%|          | 0.00/7.09k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/41.0 [00:00<?, ?B/s]
# otslp_all_fast.check:   0%|          | 0.00/146M [00:00<?, ?B/s]
# .gitignore:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# otslp_all_standard_094_clean.check:   0%|          | 0.00/213M [00:00<?, ?B/s]
# (…)artifacts%2Ftableformer%2Ftm_config.json:   0%|          | 0.00/7.09k [00:00<?, ?B/s]
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# 10:46:15 INFO - Completed 1 files (16.67%) in 0.089 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 1 files (16.67%) in 0.089 min
# 10:46:18 INFO - Completed 2 files (33.33%) in 0.146 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 2 files (33.33%) in 0.146 min
# 10:46:21 INFO - Completed 3 files (50.0%) in 0.194 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 3 files (50.0%) in 0.194 min
# 10:46:24 INFO - Completed 4 files (66.67%) in 0.242 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 4 files (66.67%) in 0.242 min
# 10:46:28 INFO - Completed 5 files (83.33%) in 0.308 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 5 files (83.33%) in 0.308 min
# 10:46:31 INFO - Completed 6 files (100.0%) in 0.357 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 6 files (100.0%) in 0.357 min
# 10:46:31 INFO - Done processing 6 files, waiting for flush() completion.
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Done processing 6 files, waiting for flush() completion.
# 10:46:31 INFO - done flushing in 0.0 sec
# INFO:data_processing.runtime.pure_python.transform_orchestrator:done flushing in 0.0 sec
# 10:46:31 INFO - Completed execution in 1.45 min, execution result 0
# INFO:data_processing.runtime.pure_python.transform_launcher:Completed execution in 1.45 min, execution result 0
# ✅ Stage:1 completed successfully
# CPU times: user 51.6 s, sys: 10 s, total: 1min 1s
# Wall time: 1min 44s

# %% [markdown]
# ### 4.2 - Inspect Generated output
#
# Here we should see one entry per input file processed.

# %%
print ("Displaying contents of : ", output_pdf2pq_dir)
output_df = read_parquet_files_as_df(output_pdf2pq_dir)
# print ("Output dimensions (rows x columns)= ", output_df.shape)
output_df.head(10)

## To display certain columns
#parquet_df[['column1', 'column2', 'column3']].head(5)
# Out:
# Displaying contents of :  output/01_pdf2pq_out
#           filename                                           contents  \
# 0       earth2.pdf  ## Earth\n\n## Solar System\n\nOur solar syste...
# 1        earth.pdf  ## Earth\n\n## Solar System\n\nOur solar syste...
# 2         mars.pdf  ## Mars\n\n## Solar System\n\nOur solar system...
# 3         spam.pdf                                           Free xxx
# 4  lorem-ipsum.pdf                Lorem ipsum Lorem ipsum Lorem ipsum
# 5   earth-copy.pdf  ## Earth\n\n## Solar System\n\nOur solar syste...
#
#    num_pages  num_tables  num_doc_elements  \
# 0          1           0                11
# 1          1           0                11
# 2          1           0                11
# 3          1           0                 2
# 4          1           0                 2
# 5          1           0                11
#
#                             document_id         document_hash  ext  \
# 0  9f9c091a-78be-452a-b300-1c9ff6eeee85  10729312978404042321  pdf
# 1  5c19e0eb-a8a3-4689-9a3e-5022d3685b96  14711865278795535908  pdf
# 2  f8058b9d-a79f-4d7a-8806-17e13d462db7   7758129997476962679  pdf
# 3  1a548f92-57bb-4404-bbde-08b0f2834c6c  10026122586747302274  pdf
# 4  ac0a2f7b-2b36-4d93-97df-f98c98537ab8   6571294142213095721  pdf
# 5  8e914b29-7398-42f8-973c-32b41a059b84  14711865278795535908  pdf
#
#                                                 hash  size  \
# 0  f039191d59ce8ba25023a844f9b99e7ef2ea4bf75a23f4...   610
# 1  6140cf695f269a3ddca6568536076756105ad3186086b2...   610
# 2  a3a4bb3b8f4f441d6d669e09f0cd07a9420d06850cf63e...   717
# 3  543ffc97aef373ee009a5f908e0358ef80d329ca7ba964...     8
# 4  bc012d063005cc02deb6c2592d1f8c3b273625edf9eec5...    35
# 5  6140cf695f269a3ddca6568536076756105ad3186086b2...   610
#
#                 date_acquired  pdf_convert_time  source_filename
# 0  2025-02-19T10:46:21.648303          2.857541       earth2.pdf
# 1  2025-02-19T10:46:18.786142          3.408339        earth.pdf
# 2  2025-02-19T10:46:28.533048          3.976753         mars.pdf
# 3  2025-02-19T10:46:31.419373          2.881931         spam.pdf
# 4  2025-02-19T10:46:24.550596          2.895987  lorem-ipsum.pdf
# 5  2025-02-19T10:46:15.329182          5.300385   earth-copy.pdf

# %% [markdown]
# ### 4.3 - Understand the output
#
# Here are some interesting attributes to note:
#
# - **filename** : original filename
# - **contents** : text
# - **document_id**: unique id (UUID) assignd to this document
# - **document_hash**: hash of documents
# - **hash** : hash of `contents` column
# - **pdf_convert_time** : time to convert this pdf in seconds
#
# **Note: you should notice the hash values are identical for the duplicate documents**
#
# Let's inspect the **contents** column.

# %%
print (output_df[output_df['filename'] == 'earth.pdf'].iloc[0,]['contents'])
# Out:
# ## Earth
#
# ## Solar System
#
# Our solar system is a vast and fascinating expanse, comprising eight planets, ﬁve dwarf planets, numerous moons, asteroids, comets, and other celestial bodies. At its center lies the star we call the Sun.
#
# For more details about our Solar system see Chapter 1.
#
# ## Earth
#
# Earth is the third planet from the Sun. It's our home planet. Earth is the only place we know of with life.
#
# Basic facts about Earth:
#
# - · Distance from the Sun: Average of 149.6 million kilometers (93 million miles)
# - · Moons: One moon, called Luna or simply "the Moon".
# - · Rotation Period: 24 hours (one day)

# %%
print (output_df[output_df['filename'] == 'spam.pdf'].iloc[0,]['contents'])
# Out:
# Free xxx

# %%
print (output_df[output_df['filename'] == 'lorem-ipsum.pdf'].iloc[0,]['contents'])
# Out:
# Lorem ipsum Lorem ipsum Lorem ipsum

# %% [markdown]
# ## Step-5:  Create DOC ID for Documents
#
# This transform annotates documents with document "ids". It supports the following transformations of the original data:
#
#  - Adding document hash: this enables the addition of a document hash-based id to the data. The hash is calculated with `hashlib.sha256(doc.encode("utf-8")).hexdigest()`. To enable this annotation, set **hash_column** to the name of the column, where you want to store it.
#  - Adding integer document id: this allows the addition of an integer document id to the data that is unique across all rows in all tables provided to the transform() method. To enable this annotation, set **int_id_column** to the name of the column, where you want to store it.
#
# **This step is a pre-requisite for fuzzy dedup** in the pipeline.
#
# [DocID documentation](https://github.com/IBM/data-prep-kit/tree/dev/transforms/universal/doc_id)

# %% [markdown]
# ### 5.1 - Execute

# %%
# %%time

from dpk_doc_id.transform_python import DocID

STAGE = 2
print (f"🏃🏼 STAGE-{STAGE}: Processing input='{output_pdf2pq_dir}' --> output='{output_docid_dir}'\n", flush=True)

result = DocID(input_folder= output_pdf2pq_dir,
                output_folder= output_docid_dir,
                doc_id_doc_column= "contents",
                doc_id_hash_column= "doc_hash",
                # doc_id_int_column= "doc_id_int",
                doc_id_int_column= "int_id_column",
                #doc_id_start_id= 5
                ).transform()

if result == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception (f"❌ Stage:{STAGE}  failed")
# Out:
# 🏃🏼 STAGE-2: Processing input='output/01_pdf2pq_out' --> output='output/02_docid_out'
# 10:50:11 INFO - Doc id parameters are : {'doc_column': 'contents', 'hash_column': 'doc_hash', 'int_column': 'int_id_column', 'start_id': 0}
# INFO:dpk_doc_id.transform:Doc id parameters are : {'doc_column': 'contents', 'hash_column': 'doc_hash', 'int_column': 'int_id_column', 'start_id': 0}
# 10:50:11 INFO - pipeline id pipeline_id
# INFO:data_processing.runtime.execution_configuration:pipeline id pipeline_id
# 10:50:11 INFO - code location None
# INFO:data_processing.runtime.execution_configuration:code location None
# 10:50:11 INFO - data factory data_ is using local data access: input_folder - output/01_pdf2pq_out output_folder - output/02_docid_out
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ is using local data access: input_folder - output/01_pdf2pq_out output_folder - output/02_docid_out
# 10:50:11 INFO - data factory data_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ max_files -1, n_sample -1
# 10:50:11 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 10:50:11 INFO - orchestrator doc_id started at 2025-02-19 10:50:11
# INFO:data_processing.runtime.pure_python.transform_orchestrator:orchestrator doc_id started at 2025-02-19 10:50:11
# 10:50:11 INFO - Number of files is 6, source profile {'max_file_size': 0.010061264038085938, 'min_file_size': 0.0055408477783203125, 'total_file_size': 0.04969310760498047}
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Number of files is 6, source profile {'max_file_size': 0.010061264038085938, 'min_file_size': 0.0055408477783203125, 'total_file_size': 0.04969310760498047}
# 10:50:11 INFO - Completed 1 files (16.67%) in 0.0 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 1 files (16.67%) in 0.0 min
# 10:50:11 INFO - Completed 2 files (33.33%) in 0.0 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 2 files (33.33%) in 0.0 min
# 10:50:11 INFO - Completed 3 files (50.0%) in 0.001 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 3 files (50.0%) in 0.001 min
# 10:50:11 INFO - Completed 4 files (66.67%) in 0.001 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 4 files (66.67%) in 0.001 min
# 10:50:11 INFO - Completed 5 files (83.33%) in 0.001 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 5 files (83.33%) in 0.001 min
# 10:50:11 INFO - Completed 6 files (100.0%) in 0.001 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 6 files (100.0%) in 0.001 min
# 10:50:11 INFO - Done processing 6 files, waiting for flush() completion.
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Done processing 6 files, waiting for flush() completion.
# 10:50:11 INFO - done flushing in 0.0 sec
# INFO:data_processing.runtime.pure_python.transform_orchestrator:done flushing in 0.0 sec
# 10:50:11 INFO - Completed execution in 0.001 min, execution result 0
# INFO:data_processing.runtime.pure_python.transform_launcher:Completed execution in 0.001 min, execution result 0
# ✅ Stage:2 completed successfully
# CPU times: user 70.9 ms, sys: 9.08 ms, total: 80 ms
# Wall time: 86.8 ms

# %% [markdown]
# ### 5.2 - Inspect Generated output
#
# You would see a new columns **doc_hash** and **int_id_column**

# %%
print ("Displaying contents of : ", output_docid_dir)
output_df = read_parquet_files_as_df(output_docid_dir)
output_df.head(10)
# Out:
# Displaying contents of :  output/02_docid_out
#           filename                                           contents  \
# 0       earth2.pdf  ## Earth\n\n## Solar System\n\nOur solar syste...
# 1        earth.pdf  ## Earth\n\n## Solar System\n\nOur solar syste...
# 2         mars.pdf  ## Mars\n\n## Solar System\n\nOur solar system...
# 3         spam.pdf                                           Free xxx
# 4  lorem-ipsum.pdf                Lorem ipsum Lorem ipsum Lorem ipsum
# 5   earth-copy.pdf  ## Earth\n\n## Solar System\n\nOur solar syste...
#
#    num_pages  num_tables  num_doc_elements  \
# 0          1           0                11
# 1          1           0                11
# 2          1           0                11
# 3          1           0                 2
# 4          1           0                 2
# 5          1           0                11
#
#                             document_id         document_hash  ext  \
# 0  9f9c091a-78be-452a-b300-1c9ff6eeee85  10729312978404042321  pdf
# 1  5c19e0eb-a8a3-4689-9a3e-5022d3685b96  14711865278795535908  pdf
# 2  f8058b9d-a79f-4d7a-8806-17e13d462db7   7758129997476962679  pdf
# 3  1a548f92-57bb-4404-bbde-08b0f2834c6c  10026122586747302274  pdf
# 4  ac0a2f7b-2b36-4d93-97df-f98c98537ab8   6571294142213095721  pdf
# 5  8e914b29-7398-42f8-973c-32b41a059b84  14711865278795535908  pdf
#
#                                                 hash  size  \
# 0  f039191d59ce8ba25023a844f9b99e7ef2ea4bf75a23f4...   610
# 1  6140cf695f269a3ddca6568536076756105ad3186086b2...   610
# 2  a3a4bb3b8f4f441d6d669e09f0cd07a9420d06850cf63e...   717
# 3  543ffc97aef373ee009a5f908e0358ef80d329ca7ba964...     8
# 4  bc012d063005cc02deb6c2592d1f8c3b273625edf9eec5...    35
# 5  6140cf695f269a3ddca6568536076756105ad3186086b2...   610
#
#                 date_acquired  pdf_convert_time  source_filename  \
# 0  2025-02-19T10:46:21.648303          2.857541       earth2.pdf
# 1  2025-02-19T10:46:18.786142          3.408339        earth.pdf
# 2  2025-02-19T10:46:28.533048          3.976753         mars.pdf
# 3  2025-02-19T10:46:31.419373          2.881931         spam.pdf
# 4  2025-02-19T10:46:24.550596          2.895987  lorem-ipsum.pdf
# 5  2025-02-19T10:46:15.329182          5.300385   earth-copy.pdf
#
#                                             doc_hash  int_id_column
# 0  f039191d59ce8ba25023a844f9b99e7ef2ea4bf75a23f4...              2
# 1  6140cf695f269a3ddca6568536076756105ad3186086b2...              1
# 2  a3a4bb3b8f4f441d6d669e09f0cd07a9420d06850cf63e...              4
# 3  543ffc97aef373ee009a5f908e0358ef80d329ca7ba964...              5
# 4  bc012d063005cc02deb6c2592d1f8c3b273625edf9eec5...              3
# 5  6140cf695f269a3ddca6568536076756105ad3186086b2...              0

# %% [markdown]
# ## Step-6: Eliminate Duplicate Documents
#
# We have 2 exact duplicates: **earth.pdf** , **earth-copy.pdf**
#
# Note how **doc_hash** for these documents are the same.
#
# [Exact dedupe information](https://github.com/IBM/data-prep-kit/tree/dev/transforms/universal/ededup)

# %% [markdown]
# ### 6.1 - Execute

# %%
# %%time

from dpk_ededup.transform_python import Ededup

STAGE = 3
print (f"🏃🏼 STAGE-{STAGE}: Processing input='{output_docid_dir}' --> output='{output_exact_dedupe_dir}'\n", flush=True)

result = Ededup(input_folder=output_docid_dir,
                output_folder=output_exact_dedupe_dir,
                ededup_doc_column="contents",
                ededup_doc_id_column="doc_hash"
                ).transform()

if result == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception (f"❌ Stage:{STAGE}  failed")
# Out:
# 🏃🏼 STAGE-3: Processing input='output/02_docid_out' --> output='output/03_exact_dedupe_out'
# 10:52:24 INFO - exact dedup params are {'doc_column': 'contents', 'doc_id_column': 'doc_hash', 'use_snapshot': False, 'snapshot_directory': None}
# INFO:dpk_ededup.transform_base:exact dedup params are {'doc_column': 'contents', 'doc_id_column': 'doc_hash', 'use_snapshot': False, 'snapshot_directory': None}
# 10:52:24 INFO - pipeline id pipeline_id
# INFO:data_processing.runtime.execution_configuration:pipeline id pipeline_id
# 10:52:24 INFO - code location None
# INFO:data_processing.runtime.execution_configuration:code location None
# 10:52:24 INFO - data factory data_ is using local data access: input_folder - output/02_docid_out output_folder - output/03_exact_dedupe_out
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ is using local data access: input_folder - output/02_docid_out output_folder - output/03_exact_dedupe_out
# 10:52:24 INFO - data factory data_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ max_files -1, n_sample -1
# 10:52:24 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 10:52:24 INFO - orchestrator ededup started at 2025-02-19 10:52:24
# INFO:data_processing.runtime.pure_python.transform_orchestrator:orchestrator ededup started at 2025-02-19 10:52:24
# 10:52:24 INFO - Number of files is 6, source profile {'max_file_size': 0.01116180419921875, 'min_file_size': 0.006641387939453125, 'total_file_size': 0.056290626525878906}
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Number of files is 6, source profile {'max_file_size': 0.01116180419921875, 'min_file_size': 0.006641387939453125, 'total_file_size': 0.056290626525878906}
# 10:52:24 INFO - Starting from the beginning
# INFO:dpk_ededup.transform_python:Starting from the beginning
# 10:52:24 INFO - Completed 1 files (16.67%) in 0.0 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 1 files (16.67%) in 0.0 min
# 10:52:24 INFO - Completed 2 files (33.33%) in 0.0 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 2 files (33.33%) in 0.0 min
# 10:52:25 INFO - Completed 3 files (50.0%) in 0.001 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 3 files (50.0%) in 0.001 min
# 10:52:25 INFO - Completed 4 files (66.67%) in 0.001 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 4 files (66.67%) in 0.001 min
# 10:52:25 INFO - Completed 5 files (83.33%) in 0.001 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 5 files (83.33%) in 0.001 min
# 10:52:25 INFO - Completed 6 files (100.0%) in 0.001 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 6 files (100.0%) in 0.001 min
# 10:52:25 INFO - Done processing 6 files, waiting for flush() completion.
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Done processing 6 files, waiting for flush() completion.
# 10:52:25 INFO - done flushing in 0.0 sec
# INFO:data_processing.runtime.pure_python.transform_orchestrator:done flushing in 0.0 sec
# 10:52:25 INFO - Completed execution in 0.002 min, execution result 0
# INFO:data_processing.runtime.pure_python.transform_launcher:Completed execution in 0.002 min, execution result 0
# ✅ Stage:3 completed successfully
# CPU times: user 94.9 ms, sys: 4.56 ms, total: 99.4 ms
# Wall time: 129 ms

# %% [markdown]
# ### 6.2 - Inspect Generated output
#
# You can see one of **earth.pdf** or **earth-copy.pdf** will be eliminated.

# %%
input_df = read_parquet_files_as_df(output_docid_dir)
output_df = read_parquet_files_as_df(output_exact_dedupe_dir)

# print ("Input data dimensions (rows x columns)= ", input_df.shape)
# print ("Output data dimensions (rows x columns)= ", output_df.shape)
print (f"Input files before exact dedupe : {input_df.shape[0]:,}")
print (f"Output files after exact dedupe : {output_df.shape[0]:,}")
print ("Duplicate files removed :  ", (input_df.shape[0] - output_df.shape[0]))

print ("Displaying contents of : ", output_exact_dedupe_dir)
output_df.head(10)
# Out:
# Input files before exact dedupe : 6
# Output files after exact dedupe : 5
# Duplicate files removed :   1
# Displaying contents of :  output/03_exact_dedupe_out
#           filename                                           contents  \
# 0       earth2.pdf  ## Earth\n\n## Solar System\n\nOur solar syste...
# 1         mars.pdf  ## Mars\n\n## Solar System\n\nOur solar system...
# 2         spam.pdf                                           Free xxx
# 3  lorem-ipsum.pdf                Lorem ipsum Lorem ipsum Lorem ipsum
# 4   earth-copy.pdf  ## Earth\n\n## Solar System\n\nOur solar syste...
#
#    num_pages  num_tables  num_doc_elements  \
# 0          1           0                11
# 1          1           0                11
# 2          1           0                 2
# 3          1           0                 2
# 4          1           0                11
#
#                             document_id         document_hash  ext  \
# 0  9f9c091a-78be-452a-b300-1c9ff6eeee85  10729312978404042321  pdf
# 1  f8058b9d-a79f-4d7a-8806-17e13d462db7   7758129997476962679  pdf
# 2  1a548f92-57bb-4404-bbde-08b0f2834c6c  10026122586747302274  pdf
# 3  ac0a2f7b-2b36-4d93-97df-f98c98537ab8   6571294142213095721  pdf
# 4  8e914b29-7398-42f8-973c-32b41a059b84  14711865278795535908  pdf
#
#                                                 hash  size  \
# 0  f039191d59ce8ba25023a844f9b99e7ef2ea4bf75a23f4...   610
# 1  a3a4bb3b8f4f441d6d669e09f0cd07a9420d06850cf63e...   717
# 2  543ffc97aef373ee009a5f908e0358ef80d329ca7ba964...     8
# 3  bc012d063005cc02deb6c2592d1f8c3b273625edf9eec5...    35
# 4  6140cf695f269a3ddca6568536076756105ad3186086b2...   610
#
#                 date_acquired  pdf_convert_time  source_filename  \
# 0  2025-02-19T10:46:21.648303          2.857541       earth2.pdf
# 1  2025-02-19T10:46:28.533048          3.976753         mars.pdf
# 2  2025-02-19T10:46:31.419373          2.881931         spam.pdf
# 3  2025-02-19T10:46:24.550596          2.895987  lorem-ipsum.pdf
# 4  2025-02-19T10:46:15.329182          5.300385   earth-copy.pdf
#
#                                             doc_hash  int_id_column removed
# 0  f039191d59ce8ba25023a844f9b99e7ef2ea4bf75a23f4...              2      []
# 1  a3a4bb3b8f4f441d6d669e09f0cd07a9420d06850cf63e...              4      []
# 2  543ffc97aef373ee009a5f908e0358ef80d329ca7ba964...              5      []
# 3  bc012d063005cc02deb6c2592d1f8c3b273625edf9eec5...              3      []
# 4  6140cf695f269a3ddca6568536076756105ad3186086b2...              0      []

# %% [markdown]
# ## Step-7: Fuzzy Dedupe
#
# In previous step, we removed **exact duplicates (identical documents)**.
#
# Fuzzy de-dupe can further filter out documents that are **not exactly identical, but nearly identical**
#
# Here is a simple example:
#
# `Our solar system is a vast and fascinating expanse`
#
# `The solar system is a vast and fascinating expanse`
#
# Only one word is different `Our` vs `The`.
#
# Imagine two documents with one extra blank line.  For our purposes they are the same.
#
# [Fuzzy dedupe documentation](https://github.com/IBM/data-prep-kit/tree/dev/transforms/universal/fdedup)
#
# ### Tweaking fuzzy matches
#
# **`jaccard_similarity_threshold`** is the parameter used to tweak similarities between documents.  It's value is between 0 and 1.0.  Values close to 1.0 means more strict checking (fewer documents will qualify).  Lower threshold means more leniant matches (more documents will qualify)
#
# Adjust this value to find what works for your documents

# %% [markdown]
# ### 7.1 - Execute

# %%
# %%time

from dpk_fdedup.transform_python import Fdedup

STAGE = 4
print (f"🏃🏼 STAGE-{STAGE}: Processing input='{output_exact_dedupe_dir}' --> output='{output_fuzzy_dedupe_dir}'\n", flush=True)

result = Fdedup(input_folder=output_exact_dedupe_dir,
                output_folder=output_fuzzy_dedupe_dir,
                contents_column= "contents",
                # document_id_column= "doc_id",
                document_id_column= "int_id_column",
                num_permutations= 112,
                num_bands= 14,
                num_minhashes_per_band= 8,
                jaccard_similarity_threshold = 0.8, # between 0 - 1.  higher means more strict checking
                operation_mode="filter_duplicates",
                # operation_mode="annotate",
                ).transform()
# if result == 0:
#     print (f"✅ Stage:{STAGE} completed successfully")
# else:
#     raise Exception (f"❌ Stage:{STAGE}  failed (result={result})")
# Out:
# 🏃🏼 STAGE-4: Processing input='output/03_exact_dedupe_out' --> output='output/04_fuzzy_dedupe_out'
# 10:53:30 INFO - Starting SignatureCalculation step
# INFO:dpk_fdedup.transform_python:Starting SignatureCalculation step
# 10:53:30 INFO - Got parameters for SignatureCalculation
# INFO:dpk_fdedup.transform_python:Got parameters for SignatureCalculation
# 10:53:30 INFO - minhash parameters are : {'document_id_column': 'int_id_column', 'contents_column': 'contents', 'seed': 42, 'num_permutations': 112, 'jaccard_similarity_threshold': 0.8, 'word_shingle_size': 5, 'num_bands': 14, 'num_minhashes_per_band': 8, 'num_segments': 1, 'shingle_option': 'word'}
# INFO:dpk_fdedup.signature_calc.transform:minhash parameters are : {'document_id_column': 'int_id_column', 'contents_column': 'contents', 'seed': 42, 'num_permutations': 112, 'jaccard_similarity_threshold': 0.8, 'word_shingle_size': 5, 'num_bands': 14, 'num_minhashes_per_band': 8, 'num_segments': 1, 'shingle_option': 'word'}
# 10:53:30 INFO - data factory scdata_ is using local configuration without input/output path
# INFO:data_processing.data_access.data_access_factory_basef367bf32-fefa-4562-8e0d-7a679e867a3b:data factory scdata_ is using local configuration without input/output path
# 10:53:30 INFO - data factory scdata_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_basef367bf32-fefa-4562-8e0d-7a679e867a3b:data factory scdata_ max_files -1, n_sample -1
# 10:53:30 INFO - data factory scdata_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_basef367bf32-fefa-4562-8e0d-7a679e867a3b:data factory scdata_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 10:53:30 INFO - pipeline id pipeline_id
# INFO:data_processing.runtime.execution_configuration:pipeline id pipeline_id
# 10:53:30 INFO - code location None
# INFO:data_processing.runtime.execution_configuration:code location None
# 10:53:30 INFO - data factory data_ is using local data access: input_folder - output/03_exact_dedupe_out output_folder - output/04_fuzzy_dedupe_out
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ is using local data access: input_folder - output/03_exact_dedupe_out output_folder - output/04_fuzzy_dedupe_out
# 10:53:30 INFO - data factory data_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ max_files -1, n_sample -1
# 10:53:30 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 10:53:30 INFO - orchestrator minhash started at 2025-02-19 10:53:30
# INFO:data_processing.runtime.pure_python.transform_orchestrator:orchestrator minhash started at 2025-02-19 10:53:30
# 10:53:30 INFO - Number of files is 6, source profile {'max_file_size': 0.011510848999023438, 'min_file_size': 0.003223419189453125, 'total_file_size': 0.050751686096191406}
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Number of files is 6, source profile {'max_file_size': 0.011510848999023438, 'min_file_size': 0.003223419189453125, 'total_file_size': 0.050751686096191406}
# 10:53:30 INFO - Completed 1 files (16.67%) in 0.004 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 1 files (16.67%) in 0.004 min
# 10:53:30 WARNING - table is empty, skipping processing
# WARNING:data_processing.transform.table_transform:table is empty, skipping processing
# 10:53:30 INFO - Completed 2 files (33.33%) in 0.004 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 2 files (33.33%) in 0.004 min
# 10:53:30 INFO - Completed 3 files (50.0%) in 0.005 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 3 files (50.0%) in 0.005 min
# 10:53:30 INFO - Completed 4 files (66.67%) in 0.005 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 4 files (66.67%) in 0.005 min
# 10:53:30 INFO - Completed 5 files (83.33%) in 0.005 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 5 files (83.33%) in 0.005 min
# 10:53:30 INFO - Completed 6 files (100.0%) in 0.005 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 6 files (100.0%) in 0.005 min
# 10:53:30 INFO - Done processing 6 files, waiting for flush() completion.
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Done processing 6 files, waiting for flush() completion.
# 10:53:30 INFO - Starting flush()
# INFO:data_processing.transform.table_transform:Starting flush()
# 10:53:31 INFO - Wrote 14 tables with a total size of 33,600 bytes
# INFO:data_processing.transform.table_transform:Wrote 14 tables with a total size of 33,600 bytes
# 10:53:31 INFO - done flushing in 0.125 sec
# INFO:data_processing.runtime.pure_python.transform_orchestrator:done flushing in 0.125 sec
# 10:53:31 INFO - Completed execution in 0.008 min, execution result 0
# INFO:data_processing.runtime.pure_python.transform_launcher:Completed execution in 0.008 min, execution result 0
# 10:53:31 INFO - SignatureCalculation completed successfully
# INFO:dpk_fdedup.transform_python:SignatureCalculation completed successfully
# 10:53:31 INFO - Starting ClusterAnalysis step
# INFO:dpk_fdedup.transform_python:Starting ClusterAnalysis step
# 10:53:31 INFO - Got parameters for ClusterAnalysis
# INFO:dpk_fdedup.transform_python:Got parameters for ClusterAnalysis
# 10:53:31 INFO - cluster parameters are : {'jaccard_similarity_threshold': 0.8, 'num_bands': 14, 'num_segments': 1, 'sort_output': False}
# INFO:dpk_fdedup.cluster_analysis.transform:cluster parameters are : {'jaccard_similarity_threshold': 0.8, 'num_bands': 14, 'num_segments': 1, 'sort_output': False}
# 10:53:31 INFO - pipeline id pipeline_id
# INFO:data_processing.runtime.execution_configuration:pipeline id pipeline_id
# 10:53:31 INFO - code location None
# INFO:data_processing.runtime.execution_configuration:code location None
# 10:53:31 INFO - data factory data_ is using local data access: input_folder - output/04_fuzzy_dedupe_out/bands output_folder - output/04_fuzzy_dedupe_out/docs_to_remove
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ is using local data access: input_folder - output/04_fuzzy_dedupe_out/bands output_folder - output/04_fuzzy_dedupe_out/docs_to_remove
# 10:53:31 INFO - data factory data_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ max_files -1, n_sample -1
# 10:53:31 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 10:53:31 INFO - orchestrator cluster started at 2025-02-19 10:53:31
# INFO:data_processing.runtime.pure_python.transform_orchestrator:orchestrator cluster started at 2025-02-19 10:53:31
# 10:53:31 INFO - Number of folders is 14
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Number of folders is 14
# 10:53:31 INFO - Completed 1 files (7.14%) in 0.002 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 1 files (7.14%) in 0.002 min
# 10:53:31 INFO - Completed 2 files (14.29%) in 0.002 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 2 files (14.29%) in 0.002 min
# 10:53:31 INFO - Completed 3 files (21.43%) in 0.002 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 3 files (21.43%) in 0.002 min
# 10:53:31 INFO - Completed 4 files (28.57%) in 0.002 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 4 files (28.57%) in 0.002 min
# 10:53:31 INFO - Completed 5 files (35.71%) in 0.003 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 5 files (35.71%) in 0.003 min
# 10:53:31 INFO - Completed 6 files (42.86%) in 0.003 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 6 files (42.86%) in 0.003 min
# 10:53:31 INFO - Completed 7 files (50.0%) in 0.003 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 7 files (50.0%) in 0.003 min
# 10:53:31 INFO - Completed 8 files (57.14%) in 0.003 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 8 files (57.14%) in 0.003 min
# 10:53:31 INFO - Completed 9 files (64.29%) in 0.003 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 9 files (64.29%) in 0.003 min
# 10:53:31 INFO - Completed 10 files (71.43%) in 0.003 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 10 files (71.43%) in 0.003 min
# 10:53:31 INFO - Completed 11 files (78.57%) in 0.004 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 11 files (78.57%) in 0.004 min
# 10:53:31 INFO - Completed 12 files (85.71%) in 0.004 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 12 files (85.71%) in 0.004 min
# 10:53:31 INFO - Completed 13 files (92.86%) in 0.004 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 13 files (92.86%) in 0.004 min
# 10:53:31 INFO - Completed 14 files (100.0%) in 0.004 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 14 files (100.0%) in 0.004 min
# 10:53:31 INFO - Done processing 14 files, waiting for flush() completion.
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Done processing 14 files, waiting for flush() completion.
# 10:53:31 INFO - done flushing in 0.0 sec
# INFO:data_processing.runtime.pure_python.transform_orchestrator:done flushing in 0.0 sec
# 10:53:31 INFO - Completed execution in 0.004 min, execution result 0
# INFO:data_processing.runtime.pure_python.transform_launcher:Completed execution in 0.004 min, execution result 0
# 10:53:31 INFO - ClusterAnalysis completed successfully
# INFO:dpk_fdedup.transform_python:ClusterAnalysis completed successfully
# 10:53:31 INFO - Starting GetDuplicateList step
# INFO:dpk_fdedup.transform_python:Starting GetDuplicateList step
# 10:53:31 INFO - Got parameters for GetDuplicateList
# INFO:dpk_fdedup.transform_python:Got parameters for GetDuplicateList
# 10:53:31 INFO - fdlist parameters are : {'docs_to_remove': 'docs_to_remove', 'consolidated_filename': 'docs_to_remove_consolidated/docs_to_remove_consolidated.parquet', 'sort_output': False}
# INFO:dpk_fdedup.get_duplicate_list.transform:fdlist parameters are : {'docs_to_remove': 'docs_to_remove', 'consolidated_filename': 'docs_to_remove_consolidated/docs_to_remove_consolidated.parquet', 'sort_output': False}
# 10:53:31 INFO - pipeline id pipeline_id
# INFO:data_processing.runtime.execution_configuration:pipeline id pipeline_id
# 10:53:31 INFO - code location None
# INFO:data_processing.runtime.execution_configuration:code location None
# 10:53:31 INFO - data factory data_ is using local data access: input_folder - output/04_fuzzy_dedupe_out output_folder - output/04_fuzzy_dedupe_out
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ is using local data access: input_folder - output/04_fuzzy_dedupe_out output_folder - output/04_fuzzy_dedupe_out
# 10:53:31 INFO - data factory data_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ max_files -1, n_sample -1
# 10:53:31 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 10:53:31 INFO - orchestrator fdlist started at 2025-02-19 10:53:31
# INFO:data_processing.runtime.pure_python.transform_orchestrator:orchestrator fdlist started at 2025-02-19 10:53:31
# 10:53:31 INFO - Number of folders is 1
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Number of folders is 1
# 10:53:31 INFO - Get Duplicate List for folder docs_to_remove
# INFO:dpk_fdedup.get_duplicate_list.transform:Get Duplicate List for folder docs_to_remove
# 10:53:31 INFO - 1 documents marked as duplicates
# INFO:dpk_fdedup.get_duplicate_list.transform:1 documents marked as duplicates
# 10:53:31 INFO - Completed 1 files (100.0%) in 0.0 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 1 files (100.0%) in 0.0 min
# 10:53:31 INFO - Done processing 1 files, waiting for flush() completion.
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Done processing 1 files, waiting for flush() completion.
# 10:53:31 INFO - done flushing in 0.0 sec
# INFO:data_processing.runtime.pure_python.transform_orchestrator:done flushing in 0.0 sec
# 10:53:31 INFO - Completed execution in 0.001 min, execution result 0
# INFO:data_processing.runtime.pure_python.transform_launcher:Completed execution in 0.001 min, execution result 0
# 10:53:31 INFO - GetDuplicateList completed successfully
# INFO:dpk_fdedup.transform_python:GetDuplicateList completed successfully
# 10:53:31 INFO - Starting DataCleaning step
# INFO:dpk_fdedup.transform_python:Starting DataCleaning step
# 10:53:31 INFO - Got parameters for DataCleaning
# INFO:dpk_fdedup.transform_python:Got parameters for DataCleaning
# 10:53:31 INFO - fdclean parameters are : {'document_id_column': 'int_id_column', 'duplicate_list_location': 'docs_to_remove_consolidated/docs_to_remove_consolidated.parquet', 'operation_mode': 'filter_duplicates'}
# INFO:dpk_fdedup.data_cleaning.transform:fdclean parameters are : {'document_id_column': 'int_id_column', 'duplicate_list_location': 'docs_to_remove_consolidated/docs_to_remove_consolidated.parquet', 'operation_mode': 'filter_duplicates'}
# 10:53:31 INFO - data factory dcdata_ is using local configuration without input/output path
# INFO:data_processing.data_access.data_access_factory_base10078c58-b501-4c62-8577-b324ec7fbecf:data factory dcdata_ is using local configuration without input/output path
# 10:53:31 INFO - data factory dcdata_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_base10078c58-b501-4c62-8577-b324ec7fbecf:data factory dcdata_ max_files -1, n_sample -1
# 10:53:31 INFO - data factory dcdata_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_base10078c58-b501-4c62-8577-b324ec7fbecf:data factory dcdata_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 10:53:31 INFO - pipeline id pipeline_id
# INFO:data_processing.runtime.execution_configuration:pipeline id pipeline_id
# 10:53:31 INFO - code location None
# INFO:data_processing.runtime.execution_configuration:code location None
# 10:53:31 INFO - data factory data_ is using local data access: input_folder - output/03_exact_dedupe_out output_folder - output/04_fuzzy_dedupe_out/cleaned
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ is using local data access: input_folder - output/03_exact_dedupe_out output_folder - output/04_fuzzy_dedupe_out/cleaned
# 10:53:31 INFO - data factory data_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ max_files -1, n_sample -1
# 10:53:31 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 10:53:31 INFO - orchestrator fdclean started at 2025-02-19 10:53:31
# INFO:data_processing.runtime.pure_python.transform_orchestrator:orchestrator fdclean started at 2025-02-19 10:53:31
# 10:53:31 INFO - Number of files is 6, source profile {'max_file_size': 0.011510848999023438, 'min_file_size': 0.003223419189453125, 'total_file_size': 0.050751686096191406}
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Number of files is 6, source profile {'max_file_size': 0.011510848999023438, 'min_file_size': 0.003223419189453125, 'total_file_size': 0.050751686096191406}
# 10:53:31 INFO - Completed 1 files (16.67%) in 0.001 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 1 files (16.67%) in 0.001 min
# 10:53:31 WARNING - table is empty, skipping processing
# WARNING:dpk_fdedup.data_cleaning.transform:table is empty, skipping processing
# 10:53:31 INFO - Completed 2 files (33.33%) in 0.001 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 2 files (33.33%) in 0.001 min
# 10:53:31 INFO - Completed 3 files (50.0%) in 0.001 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 3 files (50.0%) in 0.001 min
# 10:53:31 INFO - Completed 4 files (66.67%) in 0.001 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 4 files (66.67%) in 0.001 min
# 10:53:31 INFO - Completed 5 files (83.33%) in 0.002 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 5 files (83.33%) in 0.002 min
# 10:53:31 INFO - Completed 6 files (100.0%) in 0.002 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 6 files (100.0%) in 0.002 min
# 10:53:31 INFO - Done processing 6 files, waiting for flush() completion.
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Done processing 6 files, waiting for flush() completion.
# 10:53:31 INFO - done flushing in 0.0 sec
# INFO:data_processing.runtime.pure_python.transform_orchestrator:done flushing in 0.0 sec
# 10:53:31 INFO - Completed execution in 0.002 min, execution result 0
# INFO:data_processing.runtime.pure_python.transform_launcher:Completed execution in 0.002 min, execution result 0
# 10:53:31 INFO - DataCleaning completed successfully
# INFO:dpk_fdedup.transform_python:DataCleaning completed successfully
# CPU times: user 812 ms, sys: 160 ms, total: 973 ms
# Wall time: 1.65 s

# %% [markdown]
# ### 7.2 - Inspect Output
#
# FuzzyDedupe will write documents that are filtered in **output/04_fuzzy_dedupe_out/cleaned** folder
#
# You will notice only one **earth.pdf** made it!  So fuzzy dedupe did filter out the almost identical doc.

# %%
input_df = read_parquet_files_as_df(output_exact_dedupe_dir)
output_df = read_parquet_files_as_df(os.path.join(output_fuzzy_dedupe_dir, "cleaned"))

# print ("Input data dimensions (rows x columns)= ", input_df.shape)
# print ("Output data dimensions (rows x columns)= ", output_df.shape)
print (f"Input files before exact dedupe : {input_df.shape[0]:,}")
print (f"Output files after exact dedupe : {output_df.shape[0]:,}")
print ("Near duplicate files removed :  ", (input_df.shape[0] - output_df.shape[0]))

print ("Displaying contents of : ", output_fuzzy_dedupe_dir)
output_df.head(10)
# Out:
# Input files before exact dedupe : 5
# Output files after exact dedupe : 4
# Near duplicate files removed :   1
# Displaying contents of :  output/04_fuzzy_dedupe_out
#           filename                                           contents  \
# 0         mars.pdf  ## Mars\n\n## Solar System\n\nOur solar system...
# 1         spam.pdf                                           Free xxx
# 2  lorem-ipsum.pdf                Lorem ipsum Lorem ipsum Lorem ipsum
# 3   earth-copy.pdf  ## Earth\n\n## Solar System\n\nOur solar syste...
#
#    num_pages  num_tables  num_doc_elements  \
# 0          1           0                11
# 1          1           0                 2
# 2          1           0                 2
# 3          1           0                11
#
#                             document_id         document_hash  ext  \
# 0  f8058b9d-a79f-4d7a-8806-17e13d462db7   7758129997476962679  pdf
# 1  1a548f92-57bb-4404-bbde-08b0f2834c6c  10026122586747302274  pdf
# 2  ac0a2f7b-2b36-4d93-97df-f98c98537ab8   6571294142213095721  pdf
# 3  8e914b29-7398-42f8-973c-32b41a059b84  14711865278795535908  pdf
#
#                                                 hash  size  \
# 0  a3a4bb3b8f4f441d6d669e09f0cd07a9420d06850cf63e...   717
# 1  543ffc97aef373ee009a5f908e0358ef80d329ca7ba964...     8
# 2  bc012d063005cc02deb6c2592d1f8c3b273625edf9eec5...    35
# 3  6140cf695f269a3ddca6568536076756105ad3186086b2...   610
#
#                 date_acquired  pdf_convert_time  source_filename  \
# 0  2025-02-19T10:46:28.533048          3.976753         mars.pdf
# 1  2025-02-19T10:46:31.419373          2.881931         spam.pdf
# 2  2025-02-19T10:46:24.550596          2.895987  lorem-ipsum.pdf
# 3  2025-02-19T10:46:15.329182          5.300385   earth-copy.pdf
#
#                                             doc_hash  int_id_column removed
# 0  a3a4bb3b8f4f441d6d669e09f0cd07a9420d06850cf63e...              4      []
# 1  543ffc97aef373ee009a5f908e0358ef80d329ca7ba964...              5      []
# 2  bc012d063005cc02deb6c2592d1f8c3b273625edf9eec5...              3      []
# 3  6140cf695f269a3ddca6568536076756105ad3186086b2...              0      []

# %% [markdown]
# ## Step-8: Document Quality
#
# This handy plugin will score documents across many metrics.
#
# Here we will look for 'bad words' metric.
#
# [Document quality documentation](https://github.com/IBM/data-prep-kit/tree/dev/transforms/language/doc_quality)
#
# By default it uses [bad words collection](https://github.com/IBM/data-prep-kit/tree/dev/transforms/language/doc_quality/dpk_doc_quality/ldnoobw).  You can supply a custom file by passing an argument `bad_word_filepath=/path/to/badwords_file`

# %% [markdown]
# ### 8.1 - Execute

# %%
# %%time

from dpk_doc_quality.transform_python import DocQuality

STAGE = 5
output_fuzzy_dedupe_cleaned_dir = os.path.join(output_fuzzy_dedupe_dir, "cleaned")
print (f"🏃🏼 STAGE-{STAGE}: Processing input='{output_fuzzy_dedupe_cleaned_dir}' --> output='{output_doc_quality_dir}'\n", flush=True)

result = DocQuality(input_folder=output_fuzzy_dedupe_cleaned_dir,
                    output_folder= output_doc_quality_dir,
                    docq_text_lang = "en",
                    docq_doc_content_column ="contents",
                    ).transform()

if result == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception (f"❌ Stage:{STAGE}  failed (result={result})")
# Out:
# 🏃🏼 STAGE-5: Processing input='output/04_fuzzy_dedupe_out/cleaned' --> output='output/05_doc_quality_out'
# 10:53:57 INFO - doc_quality parameters are : {'text_lang': 'en', 'doc_content_column': 'contents', 'bad_word_filepath': '/usr/local/lib/python3.11/dist-packages/dpk_doc_quality/ldnoobw/en', 's3_cred': None, 'docq_data_factory': <data_processing.data_access.data_access_factory.DataAccessFactory object at 0x7b2133c5d9d0>}
# INFO:dpk_doc_quality.transform:doc_quality parameters are : {'text_lang': 'en', 'doc_content_column': 'contents', 'bad_word_filepath': '/usr/local/lib/python3.11/dist-packages/dpk_doc_quality/ldnoobw/en', 's3_cred': None, 'docq_data_factory': <data_processing.data_access.data_access_factory.DataAccessFactory object at 0x7b2133c5d9d0>}
# 10:53:57 INFO - data factory docq_ is using local configuration without input/output path
# INFO:data_processing.data_access.data_access_factory_base43e87709-4f29-40c3-8ff9-e0da5a020540:data factory docq_ is using local configuration without input/output path
# 10:53:57 INFO - data factory docq_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_base43e87709-4f29-40c3-8ff9-e0da5a020540:data factory docq_ max_files -1, n_sample -1
# 10:53:57 INFO - data factory docq_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_base43e87709-4f29-40c3-8ff9-e0da5a020540:data factory docq_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 10:53:57 INFO - pipeline id pipeline_id
# INFO:data_processing.runtime.execution_configuration:pipeline id pipeline_id
# 10:53:57 INFO - code location None
# INFO:data_processing.runtime.execution_configuration:code location None
# 10:53:57 INFO - data factory data_ is using local data access: input_folder - output/04_fuzzy_dedupe_out/cleaned output_folder - output/05_doc_quality_out
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ is using local data access: input_folder - output/04_fuzzy_dedupe_out/cleaned output_folder - output/05_doc_quality_out
# 10:53:57 INFO - data factory data_ max_files -1, n_sample -1
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ max_files -1, n_sample -1
# 10:53:57 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# INFO:data_processing.data_access.data_access_factory_based8bf8d49-429e-49b3-8f25-f40472cf75de:data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 10:53:57 INFO - orchestrator docq started at 2025-02-19 10:53:57
# INFO:data_processing.runtime.pure_python.transform_orchestrator:orchestrator docq started at 2025-02-19 10:53:57
# 10:53:57 INFO - Number of files is 5, source profile {'max_file_size': 0.011510848999023438, 'min_file_size': 0.0035142898559570312, 'total_file_size': 0.040172576904296875}
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Number of files is 5, source profile {'max_file_size': 0.011510848999023438, 'min_file_size': 0.0035142898559570312, 'total_file_size': 0.040172576904296875}
# 10:53:57 INFO - Load badwords found locally from /usr/local/lib/python3.11/dist-packages/dpk_doc_quality/ldnoobw/en
# INFO:dpk_doc_quality.transform:Load badwords found locally from /usr/local/lib/python3.11/dist-packages/dpk_doc_quality/ldnoobw/en
# 10:53:57 INFO - Completed 1 files (20.0%) in 0.0 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 1 files (20.0%) in 0.0 min
# 10:53:57 WARNING - table is empty, skipping processing
# WARNING:data_processing.transform.table_transform:table is empty, skipping processing
# 10:53:57 INFO - Completed 2 files (40.0%) in 0.001 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 2 files (40.0%) in 0.001 min
# 10:53:57 INFO - Completed 3 files (60.0%) in 0.001 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 3 files (60.0%) in 0.001 min
# 10:53:57 INFO - Completed 4 files (80.0%) in 0.001 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 4 files (80.0%) in 0.001 min
# 10:53:57 INFO - Completed 5 files (100.0%) in 0.001 min
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Completed 5 files (100.0%) in 0.001 min
# 10:53:57 INFO - Done processing 5 files, waiting for flush() completion.
# INFO:data_processing.runtime.pure_python.transform_orchestrator:Done processing 5 files, waiting for flush() completion.
# 10:53:57 INFO - done flushing in 0.0 sec
# INFO:data_processing.runtime.pure_python.transform_orchestrator:done flushing in 0.0 sec
# 10:53:57 INFO - Completed execution in 0.001 min, execution result 0
# INFO:data_processing.runtime.pure_python.transform_launcher:Completed execution in 0.001 min, execution result 0
# ✅ Stage:5 completed successfully
# CPU times: user 93.5 ms, sys: 9.8 ms, total: 103 ms
# Wall time: 107 ms

# %% [markdown]
# ### 8.2 - Inspect the Output
#
# We will see several new columns starting with the name **docq_**.
#
# Look at the column **docq_contain_bad_word**; this will flag documents with 'bad words'.
#
# Also inspect the column **docq_lorem_ipsum_ratio**; this will flag documents with 'lorem ipsum' text
#
# For more information see : [Doc Quality documentation](https://github.com/IBM/data-prep-kit/tree/dev/transforms/language/doc_quality)

# %%
output_df = read_parquet_files_as_df(output_doc_quality_dir)
print ("Displaying contents of : ", output_doc_quality_dir)
output_df.head()
# Out:
# Displaying contents of :  output/05_doc_quality_out
#           filename                                           contents  \
# 0         mars.pdf  ## Mars\n\n## Solar System\n\nOur solar system...
# 1         spam.pdf                                           Free xxx
# 2  lorem-ipsum.pdf                Lorem ipsum Lorem ipsum Lorem ipsum
# 3   earth-copy.pdf  ## Earth\n\n## Solar System\n\nOur solar syste...
#
#    num_pages  num_tables  num_doc_elements  \
# 0          1           0                11
# 1          1           0                 2
# 2          1           0                 2
# 3          1           0                11
#
#                             document_id         document_hash  ext  \
# 0  f8058b9d-a79f-4d7a-8806-17e13d462db7   7758129997476962679  pdf
# 1  1a548f92-57bb-4404-bbde-08b0f2834c6c  10026122586747302274  pdf
# 2  ac0a2f7b-2b36-4d93-97df-f98c98537ab8   6571294142213095721  pdf
# 3  8e914b29-7398-42f8-973c-32b41a059b84  14711865278795535908  pdf
#
#                                                 hash  size  ...  \
# 0  a3a4bb3b8f4f441d6d669e09f0cd07a9420d06850cf63e...   717  ...
# 1  543ffc97aef373ee009a5f908e0358ef80d329ca7ba964...     8  ...
# 2  bc012d063005cc02deb6c2592d1f8c3b273625edf9eec5...    35  ...
# 3  6140cf695f269a3ddca6568536076756105ad3186086b2...   610  ...
#
#   docq_mean_word_len  docq_symbol_to_word_ratio docq_sentence_count  \
# 0           4.688000                   0.032000                   8
# 1           3.500000                   0.000000                   1
# 2           5.000000                   0.000000                   1
# 3           4.541284                   0.027523                   9
#
#   docq_lorem_ipsum_ratio  docq_curly_bracket_ratio docq_contain_bad_word  \
# 0               0.000000                       0.0                 False
# 1               0.000000                       0.0                  True
# 2               0.085714                       0.0                 False
# 3               0.000000                       0.0                 False
#
#    docq_bullet_point_ratio  docq_ellipsis_line_ratio  \
# 0                 0.176471                       0.0
# 1                 0.000000                       0.0
# 2                 0.000000                       0.0
# 3                 0.176471                       0.0
#
#    docq_alphabet_word_ratio  docq_contain_common_en_words
# 0                  0.880000                          True
# 1                  1.000000                         False
# 2                  1.000000                         False
# 3                  0.880734                          True
#
# [4 rows x 27 columns]

# %% [markdown]
# ### 8.3 - Filtering 'quality' documents
#
# So from the output above we see **spam.pdf** is flagged for containing bad words (**docq_contain_bad_word=True**).
#
# Also **lorem.pdf** is flagged for place holder content **lorem ipsum**  (**docq_lorem_ipsum_ratio > 0**)
#
# We are going to filter them both out

# %%
all_docs_df = read_parquet_files_as_df(output_doc_quality_dir)

# remove documents with badwords
clean_docs_df = all_docs_df[all_docs_df['docq_contain_bad_word'] == False]

# also filter out 'lorem ipsum' text
clean_docs_df = clean_docs_df[clean_docs_df['docq_lorem_ipsum_ratio'] == 0]

clean_docs_df.head(10)
# Out:
#          filename                                           contents  \
# 0        mars.pdf  ## Mars\n\n## Solar System\n\nOur solar system...
# 3  earth-copy.pdf  ## Earth\n\n## Solar System\n\nOur solar syste...
#
#    num_pages  num_tables  num_doc_elements  \
# 0          1           0                11
# 3          1           0                11
#
#                             document_id         document_hash  ext  \
# 0  f8058b9d-a79f-4d7a-8806-17e13d462db7   7758129997476962679  pdf
# 3  8e914b29-7398-42f8-973c-32b41a059b84  14711865278795535908  pdf
#
#                                                 hash  size  ...  \
# 0  a3a4bb3b8f4f441d6d669e09f0cd07a9420d06850cf63e...   717  ...
# 3  6140cf695f269a3ddca6568536076756105ad3186086b2...   610  ...
#
#   docq_mean_word_len  docq_symbol_to_word_ratio docq_sentence_count  \
# 0           4.688000                   0.032000                   8
# 3           4.541284                   0.027523                   9
#
#   docq_lorem_ipsum_ratio  docq_curly_bracket_ratio docq_contain_bad_word  \
# 0                    0.0                       0.0                 False
# 3                    0.0                       0.0                 False
#
#    docq_bullet_point_ratio  docq_ellipsis_line_ratio  \
# 0                 0.176471                       0.0
# 3                 0.176471                       0.0
#
#    docq_alphabet_word_ratio  docq_contain_common_en_words
# 0                  0.880000                          True
# 3                  0.880734                          True
#
# [2 rows x 27 columns]

# %% [markdown]
# ## Step-9: Copy output to final output dir

# %%
import shutil

shutil.rmtree(output_final_dir, ignore_errors=True)
shutil.os.makedirs(output_final_dir, exist_ok=True)

output_final_dir_parquet = os.path.join (output_final_dir, 'pq')
shutil.os.makedirs(output_final_dir_parquet, exist_ok=True)

output_final_dir_markdown = os.path.join (output_final_dir, 'markdown')
shutil.os.makedirs(output_final_dir_markdown, exist_ok=True)

# %%
## save parquet

clean_docs_df.to_parquet(os.path.join(output_final_dir_parquet, "clean_docs.parquet"))
print (f"✅ Saved CLEAN parquet output to '{output_final_dir_parquet}'")
# Out:
# ✅ Saved CLEAN parquet output to 'output/output_final/pq'

# %%
## save markdown text

for index, row in clean_docs_df.iterrows():
    output_file_name = os.path.join (output_final_dir_markdown, row['filename'] + '.md')
    with open(output_file_name, 'w') as output_file:
        output_file.write(row['contents'])

print (f"✅ Saved CLEAN markdown output to '{output_final_dir_markdown}'")
# Out:
# ✅ Saved CLEAN markdown output to 'output/output_final/markdown'
